# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('download.csv', on_bad_lines='skip')

# %%
df.head()
# Out:
#   # This file was produced by https://exoplanet.eu
# 0                      #COLUMN name: Planet name
# 1  #COLUMN planet_status: Confirmed or candidate
# 2            #COLUMN mass: Mass (Jupiter masses)
# 3         #COLUMN mass_error_min: Min mass error
# 4         #COLUMN mass_error_max: Max mass error

# %%
df=pd.read_excel('download.xls')

# %%
df
# Out:
#       radius  radius_error_min  radius_error_max  orbital_period  \
# 0      1.152               NaN               NaN     1075.400000
# 1        NaN               NaN               NaN        4.400000
# 2        NaN               NaN               NaN    36336.700000
# 3        NaN               NaN               NaN      326.030000
# 4        NaN               NaN               NaN      516.220000
# ...      ...               ...               ...             ...
# 7408   0.292               NaN               NaN        0.054057
# 7409   0.980              0.02              0.02        0.069789
# 7410   0.680              0.07              0.07        0.043000
# 7411   1.020              0.02              0.02        0.112007
# 7412   0.490              0.04              0.04        0.024000
#
#       orbital_period_error_min  orbital_period_error_max  semi_major_axis  \
# 0                 7.000000e-01              7.000000e-01          2.05100
# ...

# %%
df.head()
# Out:
#    radius  radius_error_min  radius_error_max  orbital_period  \
# 0   1.152               NaN               NaN         1075.40
# 1     NaN               NaN               NaN            4.40
# 2     NaN               NaN               NaN        36336.70
# 3     NaN               NaN               NaN          326.03
# 4     NaN               NaN               NaN          516.22
#
#    orbital_period_error_min  orbital_period_error_max  semi_major_axis  \
# 0                    0.7000                    0.7000            2.051
# 1                    0.0004                    0.0004            0.054
# 2                 6039.4000                 6039.4000           22.210
# 3                    0.3200                    0.3200            1.290
# 4                    3.2500                    3.2500            1.540
#
#    semi_major_axis_error_min  semi_major_axis_error_max  eccentricity  ...  \
# 0                      0.087                      0.087         0.104  ...
# ...
